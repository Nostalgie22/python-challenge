# %%
from pathlib import path 
import csv

# set the file path
csvpath = path('../Resources/budget_data.csv')

# initialize variable to hold months and profit/losses
total_months = []
total = []
average_change = []
greatest_increase_in_profit = []
greatest_decrease_in_profits = []

# initialize line_num variable
line_num = 0

#open the input path as a file object
with open(csvpath,'rd') as csvfile:
    
    
    # print the datatype of the file object
    print(type(csvfile))
    print
    
    # pass in the csv file to the csv.reader() function
   #(with','as the delimiter/separator/ and return csvreader objet
csvreader = csv reader (csvfile,delimiter=',')
#print datatype of the csv reader
print(type(csvreader))
print()
# go to the next row from the start of the file
#which often the first row/reader and iterate line_num by 1
header = next(csvreader)
line_num += 1
# print the header
print(f"{header} <----HEADER")
# read each row of data after header
for row in csvheader
#print row
print (row)
#set the total_months variable equal to the value in first column
total_months = int(row[0])
total = int (row[0])
average_change = int(row[0])
greatest_increase_in_profit = int(row[0])
greatest_decrease_in_profit = int(row[0])

#initialize metric variables
count_months = 0
sum_profits_losses = 0
avg = 0
max_profit_losses = 0
min_profit_losses = 0
count_profit_losses = 0

# calculate the max,min,avg,sum count of months and count_profit_losses of the budget_data
pyth
